# %%
import sys
from pathlib import Path

src_path = (Path.cwd().parent / "src").resolve()

if str(src_path) not in {str(Path(p).resolve()) for p in sys.path if p}:
    sys.path.insert(0, str(src_path))

# %%
from sklearn.datasets import fetch_california_housing

from automl_engine.ml.automl.supervised import RegressionAnalyzer

df = fetch_california_housing(as_frame=True).frame

ra = RegressionAnalyzer(
    df,
    target_column="MedHouseVal",
    random_state=42,
    drop_unused_columns=True,
    ignore_columns=["AveBedrms"],
)

print(ra.data.dtypes)
print(ra.target_column)
print(ra.feature_columns)
print(ra.ignore_columns)
print(ra.column_types)
print(ra.random_state)
# Out:
# Longitude      float64
# AveOccup       float64
# Population     float64
# AveRooms       float64
# HouseAge       float64
# MedHouseVal    float64
# Latitude       float64
# MedInc         float64
# dtype: object
# MedHouseVal
# ['MedInc', 'HouseAge', 'AveRooms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
# ['AveBedrms']
# {}
# 42

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import KBinsDiscretizer, StandardScaler

# 数値: 欠損補完 → 標準化
num = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler()),
    ]
)

geo = KBinsDiscretizer(
    n_bins=10,
    encode="onehot-dense",
    strategy="quantile",
    quantile_method="averaged_inverted_cdf",
)

preprocess = ColumnTransformer(
    transformers=[
        ("num", num, ["MedInc", "HouseAge", "AveRooms", "Population", "AveOccup"]),
        ("geo", geo, ["Latitude", "Longitude"]),
    ],
    remainder="drop",
)

prepared_data = ra.prepare(
    preprocess=preprocess,
    cv=5,
)

for key, value in prepared_data.items():
    print(f"{key}: {value}")
# Out:
# data: {'X': array([[ 2.34476576,  0.98214266,  0.62855945, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 2.33223796, -0.60701891,  0.32704136, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.7826994 ,  1.85618152,  1.15562047, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [-1.14259331, -0.92485123, -0.09031802, ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.05458292, -0.84539315, -0.04021111, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.78012947, -1.00430931, -0.07044252, ...,  0.        ,
#          0.        ,  0.        ]]), 'y': 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MedHouseVal, Length: 20640, dtype: float64, 'is_preprocessed': True}
# cv: {'strategy': 'KFold', 'n_splits': 5, 'splits': [{'fold': 0, 'train_idx': array([    1,     2,     4, ..., 20636, 20637, 20639]), 'valid_idx': array([    0,     3,     6, ..., 20633, 20635, 20638])}, {'fold': 1, 'train_idx': array([    0,     1,     2, ..., 20637, 20638, 20639]), 'valid_idx': array([    5,     8,    14, ..., 20628, 20630, 20636])}, {'fold': 2, 'train_idx': array([    0,     1,     3, ..., 20637, 20638, 20639]), 'valid_idx': array([    2,     7,    10, ..., 20613, 20615, 20620])}, {'fold': 3, 'train_idx': array([    0,     2,     3, ..., 20637, 20638, 20639]), 'valid_idx': array([    1,     4,    12, ..., 20629, 20631, 20634])}, {'fold': 4, 'train_idx': array([    0,     1,     2, ..., 20635, 20636, 20638]), 'valid_idx': array([    9,    11,    13, ..., 20632, 20637, 20639])}]}
# overview: {'input_shape': (20640, 7), 'output_shape': (20640, 25), 'n_features_out': 25}

# %%
trained = ra.train(
    algorithms=None,          # まずはデフォルトで
    metrics=None,             # まずはデフォルトで
    primary_metric_key=None,  # デフォルトがあるなら任せる
    search_method="optuna",     # まずは optuna 推奨
    optuna_trials=50,
    optuna_timeout=None,
)

trained.summarize()
# Out:
# アルゴリズム実行:   0%|          | 0/6 [00:00<?, ?algo/s]並列実行中にエラーが発生: SVR.__init__() takes 1 positional argument but 2 were given
# [I 2025-12-29 23:23:49,116] A new study created in memory with name: no-name-02494675-da28-4519-af59-0008abbbb3cd
# [W 2025-12-29 23:23:49,118] Trial 0 failed with parameters: {} because of the following error: TypeError('LinearRegression.__init__() takes 1 positional argument but 2 were given').
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 490, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 241, in _execute_algorithm
#     est, info = _run_optuna(
#                 ^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 832, in _run_optuna
#     y=y,
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\study.py", line 490, in optimize
#     _optimize(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 67, in _optimize
#     _optimize_sequential(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 164, in _optimize_sequential
#     frozen_trial_id = _run_trial(study, func, catch)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 262, in _run_trial
#     raise func_err
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 808, in objective
#     """
#
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 355, in _run_parallel_joblib
#     )
#
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1784, in _retrieve
#     self._raise_error_fast()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1859, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 758, in get_result
#     return self._return_or_raise()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 773, in _return_or_raise
#     raise self._result
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 808, in objective
#     """
#
# TypeError: LinearRegression.__init__() takes 1 positional argument but 2 were given
# [W 2025-12-29 23:23:49,122] Trial 0 failed with value None.
# アルゴリズム 'lr' の実行中にエラーが発生: LinearRegression.__init__() takes 1 positional argument but 2 were given
# アルゴリズム 'lr' が失敗: LinearRegression.__init__() takes 1 positional argument but 2 were given
# アルゴリズム実行:  17%|█▋        | 1/6 [00:00<00:01,  3.71algo/s][I 2025-12-29 23:23:49,127] A new study created in memory with name: no-name-4faaf0e9-23ed-45ab-b053-4b3a7528cc20
# [W 2025-12-29 23:23:49,287] Trial 0 failed with parameters: {} because of the following error: ValueError('\nAll the 5 fits failed.\nIt is very likely that your model is misconfigured.\nYou can try to debug the error by setting error_score=\'raise\'.\n\nBelow are more details about the failures:\n--------------------------------------------------------------------------------\n1 fits failed with the following error:\njoblib.externals.loky.process_executor._RemoteTraceback: \n"""\nTraceback (most recent call last):\n  File "c:\\Users\\brts5\\anaconda3\\envs\\automl-engine\\Lib\\site-packages\\joblib\\externals\\loky\\process_executor.py", line 490, in _process_worker\n    r = call_item()\n        ^^^^^^^^^^^\n  File "c:\\Users\\brts5\\anaconda3\\envs\\automl-engine\\Lib\\site-packages\\joblib\\externals\\loky\\process_executor.py", line 291, in __call__\n    return self.fn(*self.args, **self.kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "c:\\Users\\brts5\\anaconda3\\envs\\automl-engine\\Lib\\site-packages\\joblib\\parallel.py", line 607, in __call__\n    return [func(*args, **kwargs) for func, args, kwargs in self.items]\n            ^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\brts5\\OneDrive\\ドキュメント\\Document\\02_Program\\portfolio\\automl-engine\\src\\automl_engine\\ml\\training\\supervised.py", line 241, in _execute_algorithm\n    est, info = _run_optuna(\n                ^^^^^^^^^^^^\n  File "C:\\Users\\brts5\\OneDrive\\ドキュメント\\Document\\02_Program\\portfolio\\automl-engine\\src\\automl_engine\\ml\\training\\supervised.py", line 832, in _run_optuna\n    y=y,\n  File "c:\\Users\\brts5\\anaconda3\\envs\\automl-engine\\Lib\\site-packages\\optuna\\study\\study.py", line 490, in optimize\n    _optimize(\n  File "c:\\Users\\brts5\\anaconda3\\envs\\automl-engine\\Lib\\site-packages\\optuna\\study\\_optimize.py", line 67, in _optimize\n    _optimize_sequential(\n  File "c:\\Users\\brts5\\anaconda3\\envs\\automl-engine\\Lib\\site-packages\\optuna\\study\\_optimize.py", line 164, in _optimize_sequential\n    frozen_trial_id = _run_trial(study, func, catch)\n                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "c:\\Users\\brts5\\anaconda3\\envs\\automl-engine\\Lib\\site-packages\\optuna\\study\\_optimize.py", line 262, in _run_trial\n    raise func_err\n  File "c:\\Users\\brts5\\anaconda3\\envs\\automl-engine\\Lib\\site-packages\\optuna\\study\\_optimize.py", line 205, in _run_trial\n    value_or_values = func(trial)\n                      ^^^^^^^^^^^\n  File "C:\\Users\\brts5\\OneDrive\\ドキュメント\\Document\\02_Program\\portfolio\\automl-engine\\src\\automl_engine\\ml\\training\\supervised.py", line 808, in objective\n    """\n        \nTypeError: SVR.__init__() takes 1 positional argument but 2 were given\n"""\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File "C:\\Users\\brts5\\OneDrive\\ドキュメント\\Document\\02_Program\\portfolio\\automl-engine\\src\\automl_engine\\ml\\training\\supervised.py", line 355, in _run_parallel_joblib\n    )\n      \n  File "c:\\Users\\brts5\\anaconda3\\envs\\automl-engine\\Lib\\site-packages\\joblib\\parallel.py", line 2072, in __call__\n    return output if self.return_generator else list(output)\n                                                ^^^^^^^^^^^^\n  File "c:\\Users\\brts5\\anaconda3\\envs\\automl-engine\\Lib\\site-packages\\joblib\\parallel.py", line 1682, in _get_outputs\n    yield from self._retrieve()\n  File "c:\\Users\\brts5\\anaconda3\\envs\\automl-engine\\Lib\\site-packages\\joblib\\parallel.py", line 1784, in _retrieve\n    self._raise_error_fast()\n  File "c:\\Users\\brts5\\anaconda3\\envs\\automl-engine\\Lib\\site-packages\\joblib\\parallel.py", line 1859, in _raise_error_fast\n    error_job.get_result(self.timeout)\n  File "c:\\Users\\brts5\\anaconda3\\envs\\automl-engine\\Lib\\site-packages\\joblib\\parallel.py", line 758, in get_result\n    return self._return_or_raise()\n           ^^^^^^^^^^^^^^^ ...
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 490, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 241, in _execute_algorithm
#     est, info = _run_optuna(
#                 ^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 832, in _run_optuna
#     y=y,
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\study.py", line 490, in optimize
#     _optimize(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 67, in _optimize
#     _optimize_sequential(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 164, in _optimize_sequential
#     frozen_trial_id = _run_trial(study, func, catch)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 262, in _run_trial
#     raise func_err
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 808, in objective
#     """
#
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 355, in _run_parallel_joblib
#     )
#
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1784, in _retrieve
#     self._raise_error_fast()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1859, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 758, in get_result
#     return self._return_or_raise()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 773, in _return_or_raise
#     raise self._result
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 816, in objective
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\utils\_param_validation.py", line 218, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\model_selection\_validation.py", line 393, in cross_validate
#     _warn_or_raise_about_fit_failures(results, error_score)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\model_selection\_validation.py", line 479, in _warn_or_raise_about_fit_failures
#     raise ValueError(all_fits_failed_message)
# ValueError:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 490, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 241, in _execute_algorithm
#     est, info = _run_optuna(
#                 ^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 832, in _run_optuna
#     y=y,
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\study.py", line 490, in optimize
#     _optimize(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 67, in _optimize
#     _optimize_sequential(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 164, in _optimize_sequential
#     frozen_trial_id = _run_trial(study, func, catch)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 262, in _run_trial
#     raise func_err
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 808, in objective
#     """
#
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 355, in _run_parallel_joblib
#     )
#
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1784, in _retrieve
#     self._raise_error_fast()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1859, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 758, in get_result
#     return self._return_or_raise()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 773, in _return_or_raise
#     raise self._result
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1329, in wrapper
#     estimator._validate_params()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 492, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'alpha' parameter of Ridge must be a float in the range [0.0, inf) or an instance of 'numpy.ndarray'. Got <optuna.trial._trial.Trial object at 0x00000212388CC0E0> instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 490, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 241, in _execute_algorithm
#     est, info = _run_optuna(
#                 ^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 832, in _run_optuna
#     y=y,
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\study.py", line 490, in optimize
#     _optimize(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 67, in _optimize
#     _optimize_sequential(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 164, in _optimize_sequential
#     frozen_trial_id = _run_trial(study, func, catch)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 262, in _run_trial
#     raise func_err
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 808, in objective
#     """
#
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 355, in _run_parallel_joblib
#     )
#
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1784, in _retrieve
#     self._raise_error_fast()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1859, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 758, in get_result
#     return self._return_or_raise()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 773, in _return_or_raise
#     raise self._result
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1329, in wrapper
#     estimator._validate_params()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 492, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'alpha' parameter of Ridge must be a float in the range [0.0, inf) or an instance of 'numpy.ndarray'. Got <optuna.trial._trial.Trial object at 0x0000021238F131A0> instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 490, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 241, in _execute_algorithm
#     est, info = _run_optuna(
#                 ^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 832, in _run_optuna
#     y=y,
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\study.py", line 490, in optimize
#     _optimize(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 67, in _optimize
#     _optimize_sequential(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 164, in _optimize_sequential
#     frozen_trial_id = _run_trial(study, func, catch)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 262, in _run_trial
#     raise func_err
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 808, in objective
#     """
#
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 355, in _run_parallel_joblib
#     )
#
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1784, in _retrieve
#     self._raise_error_fast()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1859, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 758, in get_result
#     return self._return_or_raise()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 773, in _return_or_raise
#     raise self._result
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1329, in wrapper
#     estimator._validate_params()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 492, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'alpha' parameter of Ridge must be a float in the range [0.0, inf) or an instance of 'numpy.ndarray'. Got <optuna.trial._trial.Trial object at 0x0000021238F13C50> instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 490, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 241, in _execute_algorithm
#     est, info = _run_optuna(
#                 ^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 832, in _run_optuna
#     y=y,
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\study.py", line 490, in optimize
#     _optimize(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 67, in _optimize
#     _optimize_sequential(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 164, in _optimize_sequential
#     frozen_trial_id = _run_trial(study, func, catch)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 262, in _run_trial
#     raise func_err
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 808, in objective
#     """
#
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 355, in _run_parallel_joblib
#     )
#
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1784, in _retrieve
#     self._raise_error_fast()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1859, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 758, in get_result
#     return self._return_or_raise()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 773, in _return_or_raise
#     raise self._result
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1329, in wrapper
#     estimator._validate_params()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 492, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'alpha' parameter of Ridge must be a float in the range [0.0, inf) or an instance of 'numpy.ndarray'. Got <optuna.trial._trial.Trial object at 0x0000021238F13FB0> instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 490, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 241, in _execute_algorithm
#     est, info = _run_optuna(
#                 ^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 832, in _run_optuna
#     y=y,
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\study.py", line 490, in optimize
#     _optimize(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 67, in _optimize
#     _optimize_sequential(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 164, in _optimize_sequential
#     frozen_trial_id = _run_trial(study, func, catch)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 262, in _run_trial
#     raise func_err
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 808, in objective
#     """
#
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 355, in _run_parallel_joblib
#     )
#
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1784, in _retrieve
#     self._raise_error_fast()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1859, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 758, in get_result
#     return self._return_or_raise()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 773, in _return_or_raise
#     raise self._result
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1329, in wrapper
#     estimator._validate_params()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 492, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'alpha' parameter of Ridge must be a float in the range [0.0, inf) or an instance of 'numpy.ndarray'. Got <optuna.trial._trial.Trial object at 0x00000212388CF110> instead.
#
# [W 2025-12-29 23:23:49,290] Trial 0 failed with value None.
# アルゴリズム 'ridge' の実行中にエラーが発生:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 490, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 241, in _execute_algorithm
#     est, info = _run_optuna(
#                 ^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 832, in _run_optuna
#     y=y,
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\study.py", line 490, in optimize
#     _optimize(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 67, in _optimize
#     _optimize_sequential(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 164, in _optimize_sequential
#     frozen_trial_id = _run_trial(study, func, catch)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 262, in _run_trial
#     raise func_err
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 808, in objective
#     """
#
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 355, in _run_parallel_joblib
#     )
#
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1784, in _retrieve
#     self._raise_error_fast()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1859, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 758, in get_result
#     return self._return_or_raise()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 773, in _return_or_raise
#     raise self._result
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1329, in wrapper
#     estimator._validate_params()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 492, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'alpha' parameter of Ridge must be a float in the range [0.0, inf) or an instance of 'numpy.ndarray'. Got <optuna.trial._trial.Trial object at 0x00000212388CC0E0> instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 490, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 241, in _execute_algorithm
#     est, info = _run_optuna(
#                 ^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 832, in _run_optuna
#     y=y,
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\study.py", line 490, in optimize
#     _optimize(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 67, in _optimize
#     _optimize_sequential(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 164, in _optimize_sequential
#     frozen_trial_id = _run_trial(study, func, catch)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 262, in _run_trial
#     raise func_err
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 808, in objective
#     """
#
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 355, in _run_parallel_joblib
#     )
#
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1784, in _retrieve
#     self._raise_error_fast()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1859, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 758, in get_result
#     return self._return_or_raise()
# ...
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 67, in _optimize
#     _optimize_sequential(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 164, in _optimize_sequential
#     frozen_trial_id = _run_trial(study, func, catch)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 262, in _run_trial
#     raise func_err
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 808, in objective
#     """
#
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 355, in _run_parallel_joblib
#     )
#
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1784, in _retrieve
#     self._raise_error_fast()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1859, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 758, in get_result
#     return self._return_or_raise()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 773, in _return_or_raise
#     raise self._result
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1329, in wrapper
#     estimator._validate_params()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 492, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'n_estimators' parameter of RandomForestRegressor must be an int in the range [1, inf). Got <optuna.trial._trial.Trial object at 0x000002120C976030> instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 490, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 241, in _execute_algorithm
#     est, info = _run_optuna(
#                 ^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 832, in _run_optuna
#     y=y,
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\study.py", line 490, in optimize
#     _optimize(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 67, in _optimize
#     _optimize_sequential(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 164, in _optimize_sequential
#     frozen_trial_id = _run_trial(study, func, catch)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 262, in _run_trial
#     raise func_err
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 808, in objective
#     """
#
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 355, in _run_parallel_joblib
#     )
#
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1784, in _retrieve
#     self._raise_error_fast()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1859, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 758, in get_result
#     return self._return_or_raise()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 773, in _return_or_raise
#     raise self._result
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1329, in wrapper
#     estimator._validate_params()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 492, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'n_estimators' parameter of RandomForestRegressor must be an int in the range [1, inf). Got <optuna.trial._trial.Trial object at 0x00000212388CE5A0> instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 490, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 241, in _execute_algorithm
#     est, info = _run_optuna(
#                 ^^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 832, in _run_optuna
#     y=y,
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\study.py", line 490, in optimize
#     _optimize(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 67, in _optimize
#     _optimize_sequential(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 164, in _optimize_sequential
#     frozen_trial_id = _run_trial(study, func, catch)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 262, in _run_trial
#     raise func_err
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\optuna\study\_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 808, in objective
#     """
#
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\brts5\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py", line 355, in _run_parallel_joblib
#     )
#
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1784, in _retrieve
#     self._raise_error_fast()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 1859, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 758, in get_result
#     return self._return_or_raise()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\joblib\parallel.py", line 773, in _return_or_raise
#     raise self._result
# TypeError: SVR.__init__() takes 1 positional argument but 2 were given
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 1329, in wrapper
#     estimator._validate_params()
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\base.py", line 492, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\brts5\anaconda3\envs\automl-engine\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'n_estimators' parameter of RandomForestRegressor must be an int in the range [1, inf). Got <optuna.trial._trial.Trial object at 0x00000212388E8B00> instead.
#
# アルゴリズム実行: 100%|██████████| 6/6 [00:00<00:00,  6.64algo/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 trained = ra.train(
#       2     algorithms=None,          # まずはデフォルトで
#       3     metrics=None,             # まずはデフォルトで
#       4     primary_metric_key=None,  # デフォルトがあるなら任せる
#       5     search_method="optuna",     # まずは optuna 推奨
#       6     optuna_trials=50,
#       7     optuna_timeout=None,
#       8 )
#      10 trained.summarize()
#
# File ~\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\automl\supervised.py:226, in RegressionAnalyzer.train(self, algorithms, metrics, primary_metric_key, search_method, optuna_trials, optuna_timeout)
#     223 self.optuna_timeout = validated.optuna_timeout
#     225 # 学習・評価・探索を実行
# --> 226 self.fitted_model, self.model_info = run_supervised(
#     227     X=self.data[self.feature_columns],
#     228     y=self.data[self.target_column],
#     229     algorithms=self.algorithms,
#     230     metrics=self.metrics,
#     231     primary_metric_key=self.primary_metric_key,
#     232     preprocess=self.preprocess,
#     233     cv=self.cv,
#     234     search_method=self.search_method,
#     235     optuna_trials=self.optuna_trials,
#     236     optuna_timeout=self.optuna_timeout,
#     237 )
#     239 # 学習完了フラグを立てる
#     240 self._is_trained = True
#
# File ~\OneDrive\ドキュメント\Document\02_Program\portfolio\automl-engine\src\automl_engine\ml\training\supervised.py:169, in run_supervised(X, y, algorithms, metrics, primary_metric_key, preprocess, cv, search_method, optuna_trials, optuna_timeout, sample_weight, groups, n_jobs, n_jobs_cv, parallel_backend, algorithm_timeout)
#     167 # 全アルゴリズムが失敗した場合は例外を送出
#     168 if not estimators:
# --> 169     raise RuntimeError(
#     170         f"全アルゴリズムが失敗しました。失敗アルゴリズム: {progress_info['failed']}"
#     171     )
#     173 logger.info(
#     174     f"並列実行完了: 成功={len(estimators)}, 失敗={len(progress_info['failed'])}"
#     175 )
#     177 # 結果を返す
#
# RuntimeError: 全アルゴリズムが失敗しました。失敗アルゴリズム: ['lr', 'ridge', 'lasso', 'elastic_net', 'svr', 'rf']

# %%
trained.model_info
# Out:
# {'lr': {'search_method': 'grid',
#   'cv_scores_mean': {'r2': 0.6290163223465549,
#    'mae': -0.5184261491181886,
#    'rmse': -0.702571819275918},
#   'primary_score_mean': 0.6290163223465549},
#  'ridge': {'search_method': 'grid',
#   'cv_scores_mean': {'r2': 0.6290152894473285,
#    'mae': -0.5183554034655334,
#    'rmse': -0.7025728634252498},
#   'primary_score_mean': 0.6290152894473285},
#  'lasso': {'search_method': 'grid',
#   'cv_scores_mean': {'r2': -0.00028167420145837064,
#    'mae': -0.9117578574805592,
#    'rmse': -1.1539411323193556},
#   'primary_score_mean': -0.00028167420145837064},
#  'elastic_net': {'search_method': 'grid',
#   'cv_scores_mean': {'r2': 0.2045898730925761,
#    'mae': -0.8117304900533838,
#    'rmse': -1.029000064911576},
#   'primary_score_mean': 0.2045898730925761},
#  'svr': {'search_method': 'grid',
#   'cv_scores_mean': {'r2': 0.7619114948252712,
#    'mae': -0.36651412832203734,
#    'rmse': -0.5624364230261334},
#   'primary_score_mean': 0.7619114948252712},
#  'rf': {'search_method': 'grid',
#   'cv_scores_mean': {'r2': 0.75683257115539,
#    'mae': -0.38667792521802347,
#    'rmse': -0.5687504896624931},
#   'primary_score_mean': 0.75683257115539}}

# %%
trained.estimators_
# Out:
# {}
